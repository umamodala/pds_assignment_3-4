# %%
import squarify

# Calculate the mean and max glucose for both sample and population
glucose_values = [
    sample_glucose_mean, population_glucose_mean,
    sample_glucose_max, population_glucose_max
]
labels = ['Sample Mean', 'Population Mean', 'Sample Max', 'Population Max']
colors = ['blue', 'green', 'red', 'orange']

# Create a treemap for visual comparison
plt.figure(figsize=(14, 6))
squarify.plot(sizes=glucose_values, label=labels, color=colors, alpha=0.7)
plt.title('Comparison of Glucose Values')
plt.axis('off')  # Remove axis
plt.show()

# %% [markdown]
# The above is comparision of glucose
# 2 A)
# set a seed (to ensure work reproducibility) and take a random sample of 25 observations and
# find the mean Glucose and highest Glucose values of this sample and compare these statistics
# with the population statistics of the same variable. You should use charts for this comparison

# %%
pip install squarify

# %% [markdown]
# 2 B)
# Find the 98th percentile of BMI of your sample and the population and compare the results
# using charts.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample BMI data
sample_bmi_data = sample_data['BMI']
population_bmi_data = diabetes_data['BMI']

# Create histogram for sample BMI data
plt.figure(figsize=(8, 5))
plt.hist(sample_bmi_data, bins=30, color='purple', alpha=0.7, label='Sample BMI')
plt.axvline(sample_bmi_98th, color='purple', linestyle='dashed', linewidth=2, label='Sample 98th Percentile')

# Create histogram for population BMI data
plt.hist(population_bmi_data, bins=30, color='cyan', alpha=0.7, label='Population BMI')
plt.axvline(population_bmi_98th, color='cyan', linestyle='dashed', linewidth=2, label='Population 98th Percentile')

plt.title('Comparison of BMI Distributions')
plt.xlabel('BMI Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2 C)
# Using bootstrap (replace= True), create 500 samples (of 150 observation each) from the
# population and find the average mean, standard deviation and percentile for BloodPressure and
# compare this with these statistics from the population for the same variable. Again, you should
# create charts for this comparison. Report on your findings

# %%
pip install plotly

# %%
import plotly.graph_objs as go

# Create trace for the first funnel chart
trace1 = go.Funnel(
    y=['Population', 'Bootstrap Stds', 'Bootstrap Percentiles'],
    x=[population_bp_std, population_bp_std, population_bp_98th],
    textinfo='value+percent previous',
    marker=dict(
        color='lightblue',
        opacity=0.7
    )
)

# Create trace for the second funnel chart
trace2 = go.Funnel(
    y=['Population', 'Bootstrap Stds', 'Bootstrap Percentiles'],
    x=[population_bp_std, population_bp_std, population_bp_98th],
    textinfo='value+percent previous',
    marker=dict(
        color='lightgreen',
        opacity=0.7
    )
)

# Create trace for the third funnel chart
trace3 = go.Funnel(
    y=['Population', 'Bootstrap Stds', 'Bootstrap Percentiles'],
    x=[population_bp_std, population_bp_std, population_bp_98th],
    textinfo='value+percent previous',
    marker=dict(
        color='lightcoral',
        opacity=0.7
    )
)

# Create figure
fig = go.Figure(data=[trace1, trace2, trace3])

# Update layout
fig.update_layout(
    title='Funnel Charts for Blood Pressure Statistics',
    xaxis=dict(title='Blood Pressure Statistics'),
    yaxis=dict(title='Category'),
    showlegend=False
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# OBSERVATION:
# The bootstrap means show that the samples have a decent representation of the population since they cluster around the population mean.
#
# - The bootstrap samples exhibit consistent variability as compared to the population, as evidenced by the clustering of the standard deviations.
